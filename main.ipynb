# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
# import data into pandas
df = pd.read_csv('Officer_JO Moral Alignment Ranking 2024 (Responses) - Form Responses 1.csv')
df.head()
# Out:
#             Timestamp         Name  Lawful - Chaotic  Evil - Good  \
# 0  3/19/2024 12:51:38          cat               7.0          8.0
# 1  3/19/2024 12:52:03  Raymond Sun              10.0          0.0
# 2  3/19/2024 12:54:01      Alex Lu               NaN          NaN
# 3  3/19/2024 12:54:57  Zhikai Tang               3.0          5.0
# 4  3/19/2024 12:58:07     Zoie Lee               6.0          5.0
#
#    Lawful - Chaotic.1  Evil - Good.1  Lawful - Chaotic.2  Evil - Good.2  \
# 0                   2             10                   8              3
# 1                   0             10                  10             10
# 2                   2              7                   9              3
# 3                   1             10                   8              9
# 4                   1              9                   7              5
#
#    Lawful - Chaotic.3  Evil - Good.3  ...  Lawful - Chaotic.32  \
# 0                   6              6  ...                  7.0
# 1                   6              6  ...                  NaN
# 2                   8              6  ...                  9.0
# 3                   3              3  ...                  6.0
# 4                   6              7  ...                  6.0
#
#    Evil - Good.32  Lawful - Chaotic.33  Evil - Good.33  Lawful - Chaotic.34  \
# 0             7.0                  7.0             3.0                  3.0
# 1             NaN                  NaN             NaN                  NaN
# 2             5.0                  9.0             3.0                  1.0
# 3             8.0                  4.0             5.0                  7.0
# 4             6.0                  6.0             6.0                  0.0
#
#    Evil - Good.34  Lawful - Chaotic.35  Evil - Good.35  Lawful - Chaotic.36  \
# 0             7.0                  2.0             2.0                  NaN
# 1             NaN                  NaN             NaN                  NaN
# 2             9.0                  8.0             2.0                  NaN
# 3             3.0                  5.0             5.0                  2.0
# 4            10.0                  0.0            10.0                  5.0
#
#    Evil - Good.36
# 0             NaN
# 1             NaN
# 2             6.0
# 3             5.0
# 4             5.0
#
# [5 rows x 76 columns]

# %%
# clean up csv
df = df.drop(df.columns[:2], axis=1)
names = ['Alex Lu', 'Shawn Hatcher', 'Selina Wu', 'Jessica Yin', 'Raymond Sun', 'Naomi Norton', 'Cris Ferreon', 'Marcel Lee', 'Jayden Lu', 'Cindy Chai', 'Victoria Vuong', 'Cat Li', 'Jing Zhang', 'Zhikai Tang', 'Elaina Lan', 'Zoie Lee', 'Timmy Huang', 'Michael Ouyang', 'Zijing Lian', 'Aaron Hew', 'Andrew Lee', 'Shuhan Sun', 'Rohit Bandi', 'Nick Nguyen', 'Jessie Chen', 'Crystal Lee', 'Diana Yang', 'Josh Dong', 'Audrey Tan', 'Jordan Chen', 'Jason Li', 'Aaron Hu', 'Corn Wang', 'Diane Guo', 'Jely Lin', 'Annie Teng', 'Cyndi Liang']
columnLables = []
# Iterate over each name and generate two variations
for name in names:
    lawful_chaotic = name + " LawfulChaotic"
    evil_good = name + " EvilGood"
    columnLables.extend([lawful_chaotic, evil_good])
df.columns = columnLables
display(df)
# Out:
#     Alex Lu LawfulChaotic  Alex Lu EvilGood  Shawn Hatcher LawfulChaotic  \
# 0                     7.0               8.0                            2
# 1                    10.0               0.0                            0
# 2                     NaN               NaN                            2
# 3                     3.0               5.0                            1
# 4                     6.0               5.0                            1
# 5                     7.0               4.0                            3
# 6                     3.0               9.0                            5
# 7                     7.0               5.0                            3
# 8                     7.0               6.0                            6
# 9                     8.0               8.0                            3
# 10                    6.0               7.0                            2
# 11                   10.0               0.0                            0
# 12                    3.0               6.0                            2
# 13                    7.0               8.0                            0
# 14                    8.0               4.0                            3
# 15                    7.0               4.0                            3
# 16                    2.0               8.0                            0
# 17                   10.0               8.0                            2
# 18                    8.0               5.0                            3
#
#     Shawn Hatcher EvilGood  Selina Wu LawfulChaotic  Selina Wu EvilGood  \
# 0                       10                        8                   3
# 1                       10                       10                  10
# 2                        7                        9                   3
# 3                       10                        8                   9
# 4                        9                        7                   5
# 5                        5                        9                   7
# 6                        6                        0                   0
# 7                       10                       10                   0
# 8                        8                        2                   7
# 9                       10                       10                   1
# 10                       8                       10                   5
# 11                       0                       10                   0
# 12                       8                        3                   5
# 13                       6                       10                   3
# 14                       7                        1                   2
# 15                       8                        8                   9
# 16                       9                        7                   6
# 17                       9                        1                   2
# 18                       9                        6                   6
#
#     Jessica Yin LawfulChaotic  Jessica Yin EvilGood  \
# 0                           6                     6
# 1                           6                     6
# 2                           8                     6
# 3                           3                     3
# 4                           6                     7
# 5                           2                     5
# 6                           5                     4
# 7                           7                     8
# 8                           5                     8
# 9                           7                     5
# 10                          4                     5
# 11                         10                     0
# 12                          8                     5
# 13                         10                     0
# 14                         10                     7
# 15                          8                     7
# 16                          7                     4
# 17                          8                     3
# 18                          5                     5
#
#     Raymond Sun LawfulChaotic  Raymond Sun EvilGood  ...  \
# 0                           2                     5  ...
# 1                           0                    10  ...
# 2                           2                     5  ...
# 3                           6                     1  ...
# 4                           5                     5  ...
# 5                           8                     7  ...
# 6                           2                     9  ...
# 7                           8                     0  ...
# 8                           2                     5  ...
# 9                           2                     4  ...
# 10                          5                     5  ...
# 11                          0                     0  ...
# 12                          5                     4  ...
# 13                          5                     7  ...
# 14                          8                     2  ...
# 15                          3                     1  ...
# 16                          3                     5  ...
# 17                          2                     1  ...
# 18                          6                     3  ...
#
#     Corn Wang LawfulChaotic  Corn Wang EvilGood  Diane Guo LawfulChaotic  \
# 0                       7.0                 7.0                      7.0
# 1                       NaN                 NaN                      NaN
# 2                       9.0                 5.0                      9.0
# 3                       6.0                 8.0                      4.0
# 4                       6.0                 6.0                      6.0
# 5                      10.0                10.0                      4.0
# 6                       7.0                 8.0                     10.0
# 7                       8.0                10.0                     10.0
# 8                       8.0                 6.0                      7.0
# 9                       7.0                 9.0                      7.0
# 10                      6.0                 4.0                     10.0
# 11                      0.0                 0.0                     10.0
# 12                     10.0                 5.0                      7.0
# 13                      7.0                 7.0                     10.0
# 14                      9.0                 7.0                      8.0
# 15                      6.0                 7.0                      NaN
# 16                      7.0                 5.0                      6.0
# 17                      7.0                 6.0                      4.0
# 18                      7.0                 7.0                      7.0
#
#     Diane Guo EvilGood  Jely Lin LawfulChaotic  Jely Lin EvilGood  \
# 0                  3.0                     3.0                7.0
# 1                  NaN                     NaN                NaN
# 2                  3.0                     1.0                9.0
# 3                  5.0                     7.0                3.0
# 4                  6.0                     0.0               10.0
# 5                  8.0                     1.0               10.0
# 6                  8.0                     0.0               10.0
# 7                  0.0                     0.0               10.0
# 8                  6.0                     2.0                8.0
# 9                  2.0                     1.0                9.0
# 10                 2.0                     3.0                7.0
# 11                 0.0                     0.0                0.0
# 12                 2.0                     3.0                7.0
# 13                 7.0                     0.0               10.0
# 14                 5.0                     5.0                9.0
# 15                 NaN                     7.0                2.0
# 16                 6.0                     0.0                6.0
# 17                 6.0                     1.0                8.0
# 18                 4.0                     3.0                6.0
#
#     Annie Teng LawfulChaotic  Annie Teng EvilGood  Cyndi Liang LawfulChaotic  \
# 0                        2.0                  2.0                        NaN
# 1                        NaN                  NaN                        NaN
# 2                        8.0                  2.0                        NaN
# 3                        5.0                  5.0                        2.0
# 4                        0.0                 10.0                        5.0
# 5                        0.0                 10.0                        0.0
# 6                        3.0                  5.0                        7.0
# 7                        8.0                  7.0                        5.0
# 8                        6.0                  8.0                        6.0
# 9                        2.0                  4.0                        1.0
# 10                       7.0                  6.0                        7.0
# 11                       0.0                  0.0                        0.0
# 12                       4.0                  4.0                        7.0
# 13                       3.0                  7.0                        2.0
# 14                       8.0                  5.0                        5.0
# 15                       3.0                  3.0                        4.0
# 16                       4.0                  7.0                        6.0
# 17                       6.0                  4.0                        5.0
# 18                       9.0                  8.0                        6.0
#
#     Cyndi Liang EvilGood
# 0                    NaN
# 1                    NaN
# 2                    6.0
# 3                    5.0
# 4                    5.0
# 5                    8.0
# 6                    8.0
# 7                    5.0
# 8                    7.0
# 9                    8.0
# 10                   7.0
# 11                   0.0
# 12                   6.0
# 13                   7.0
# 14                   5.0
# 15                   7.0
# 16                   8.0
# 17                   5.0
# 18                   8.0
#
# [19 rows x 74 columns]

# %%
for x in range(len(names)):
    ax = df.plot.scatter(x=df.columns[x*2], y=df.columns[x*2+1],xlim=(0, 10), ylim=(0, 10))
    ax.axvline(x=5, color='black', linestyle='--')
    ax.axhline(y=5, color='black', linestyle='--')
    ax.set_xticks(range(11))
    ax.set_yticks(range(11))
    ax.grid(which='both')
    ax.set_xlabel(r'Lawful $\qquad\qquad\qquad\qquad\qquad\qquad\qquad\qquad\qquad\qquad\qquad\qquad\qquad\qquad\quad$ Chaotic')
    ax.set_ylabel(r'Evil $\qquad\qquad\qquad\qquad\qquad\qquad\qquad\qquad\qquad\qquad\qquad$  Good')
    ax.set_title(names[x]+'\'s Moral Alignment Responses')
    plt.savefig(f'{names[x].replace(" ", "")}Responses.png')
# Out:
# C:\Users\Alex\anaconda3\Lib\site-packages\pandas\plotting\_matplotlib\core.py:512: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`). Consider using `matplotlib.pyplot.close()`.
#   fig = self.plt.figure(figsize=self.figsize)

# %%
avg_df = pd.DataFrame(df.mean(), columns=['Average'])
display(avg_df)
even_rows = avg_df[::2]
odd_rows = avg_df[1::2]
even_rows.columns = ['Lawful - Chaotic']
odd_rows.columns = ['Evil - Good']
odd_rows.reset_index(drop=True, inplace=True)
even_rows.reset_index(drop=True, inplace=True)
# display(even_rows)
# display(odd_rows)
result_df = pd.concat([even_rows, odd_rows], axis=1)
result_df.index = names
display(result_df)
# Out:
#                               Average
# Alex Lu LawfulChaotic        6.611111
# Alex Lu EvilGood             5.555556
# Shawn Hatcher LawfulChaotic  2.157895
# Shawn Hatcher EvilGood       7.842105
# Selina Wu LawfulChaotic      6.789474
# ...                               ...
# Jely Lin EvilGood            7.277778
# Annie Teng LawfulChaotic     4.333333
# Annie Teng EvilGood          5.388889
# Cyndi Liang LawfulChaotic    4.250000
# Cyndi Liang EvilGood         6.176471
#
# [74 rows x 1 columns]
#                 Lawful - Chaotic  Evil - Good
# Alex Lu                 6.611111     5.555556
# Shawn Hatcher           2.157895     7.842105
# Selina Wu               6.789474     4.368421
# Jessica Yin             6.578947     4.947368
# Raymond Sun             3.894737     4.157895
# Naomi Norton            1.631579     8.368421
# Cris Ferreon            3.631579     7.210526
# Marcel Lee              7.894737     2.684211
# Jayden Lu               6.210526     5.473684
# Cindy Chai              3.000000     7.368421
# Victoria Vuong          7.055556     4.722222
# Cat Li                  2.777778     7.277778
# Jing Zhang              2.157895     8.263158
# Zhikai Tang             6.000000     4.684211
# Elaina Lan              5.368421     7.578947
# Zoie Lee                3.052632     5.684211
# Timmy Huang             4.611111     4.555556
# Michael Ouyang          7.157895     5.052632
# Zijing Lian             4.444444     4.666667
# Aaron Hew               5.263158     5.736842
# Andrew Lee              5.421053     5.631579
# Shuhan Sun              4.105263     5.789474
# Rohit Bandi             7.368421     2.263158
# Nick Nguyen             7.684211     5.210526
# Jessie Chen             4.684211     5.947368
# Crystal Lee             3.777778     5.388889
# Diana Yang              4.888889     5.722222
# Josh Dong               4.315789     5.894737
# Audrey Tan              8.157895     7.368421
# Jordan Chen             3.666667     5.166667
# Jason Li                4.066667     4.933333
# Aaron Hu                2.875000     6.125000
# Corn Wang               7.055556     6.500000
# Diane Guo               7.411765     4.294118
# Jely Lin                2.055556     7.277778
# Annie Teng              4.333333     5.388889
# Cyndi Liang             4.250000     6.176471

# %%
ax = result_df.plot.scatter(x='Lawful - Chaotic', y='Evil - Good',xlim=(0, 10), ylim=(0, 10), figsize=(20, 20))
ax.axvline(x=5, color='black', linestyle='--')
ax.axhline(y=5, color='black', linestyle='--')
ax.set_xticks(range(11))
ax.set_yticks(range(11))
ax.grid(which='both')
xspace = '\qquad'*50
yspace = '\qquad'*50
ax.set_xlabel(rf'Lawful ${xspace}$ Chaotic')
ax.set_ylabel(rf'Evil ${yspace}$  Good')
ax.set_title('CSA JO Officerboard Moral Alignment')
for idx, row in result_df.iterrows():
    ax.annotate(idx, (row['Lawful - Chaotic'], row['Evil - Good']), xytext=(5,-5),
                textcoords='offset points', family='sans-serif', fontsize=10)
    
r_value = result_df['Lawful - Chaotic'].corr(result_df['Evil - Good'])
print(r_value)
csa = result_df.mean()
print(csa)
# Out:
# -0.5926789477578571
# Lawful - Chaotic    4.929933
# Evil - Good         5.710202
# dtype: float64
